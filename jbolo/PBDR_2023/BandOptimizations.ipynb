# %% [markdown]
# # CMB-S4 Band Optimizations (for NET)
# In this notebook we use a logistic-function model of bandpass shapes to explore various metrics relevant to CMB-S4's bands, including optimization of center frequency and width.
#
# (This notebook predates the implementation of logistic band shapes in jbolo, so we use an external function here, with the same formulas).

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import yaml
import sys
#sys.path.insert(0,'/Users/ruhl/code/jbolo/python/')
from  jbolo_funcs import *

# %matplotlib inline
plt.rcParams.update({'font.size': 12})
plt.rcParams['figure.figsize'] = [8, 10]

# %% [markdown]
# # Logistic Bandshapes
# First let's create a function that builds a somewhat realistic-looking band shape given some input parameters.

# %%
def logistic_bandmodel(nuvec, nu0, dnu,a,n):
    '''Returns a logistic-function band model, 
       peaking at unity, given input central frequency 
       and bandwidth in GHz.
       
       Note that we are going to replace all values < 1e-5 with 1e-5,
       to keep some divisions from blowing up.
       
       nuvec:  vector of frequencies at which to return the function
       nu0:  center frequency
       dnu:  bandwidth
       a: prefactor used in logistic model
       n: exponent used in logistic model
       
       Note:  a and n control the steepness of the edges.
       
       band = f1*f2, where f1 is a highpass, f2 is a lowpass
       k1 = a*(20/lowedge)**n
       k2 = a*(20/highedge)**m
       f1 =     1/(1+np.exp(-k1*(nu-nu_lowedge )))
       f2 = 1 - 1/(1+np.exp(-k2*(nu-nu_highedge)))
    '''
    nu_lowedge  = nu0-dnu/2
    nu_highedge = nu0+dnu/2
    # I tuned aa and nn by hand to "best fit by eye" (globally) 
    # the bands Sara provided in the first plot below.
    #aa = 2     # smaller aa gives broader tails at all frequency bands
    #nn = 0.7   # larger nn gives broader tails at higher frequency bands
    k1 = a*(20/nu_lowedge)**n
    f1 = 1/(1+np.exp(-k1*(nuvec-nu_lowedge )))
    k2 = a*(20/nu_highedge)**n
    f2 = 1-1/(1+np.exp(-k2*(nuvec-nu_highedge)))
    f = f1*f2
    f = f/np.max(f) # normalize to unity
    f = np.where(f<1e-5,1e-5,f)
    return f

# Plot some examples
nuvec = np.linspace(100,200,500)
plt.clf()
plt.subplot(2,1,1)
for n in [0.3,0.5,0.7,0.9]:
  f = logistic_bandmodel(nuvec,150,50,2.0, n)
  plt.plot(nuvec,f,label=str(n))
plt.legend()
plt.title('a = 2.0, varying n')
plt.grid()

plt.subplot(2,1,2)
for a in [1.0, 2.0, 3.0, 10.0]:
  f = logistic_bandmodel(nuvec,150,50,a, 0.7)
  plt.plot(nuvec,f,label=str(a))
plt.legend()
plt.xlabel('frequency (GHz)')
plt.title('n = 0.7, varying a')
plt.grid()

# %% [markdown]
# We'll use n = 0.7, a = 2.0 as our default because those do a reasonable job of replicating the band edges of the simulations done by Jeff McMahon.   If we want to compare that with a very square band, we can raise 'a' high and set 'n' low.
#
# With that function in place, let's use jbolo to calculate P_optical and NET for an array of band centers and widths, for each channel in the yaml file.
#
# In this example we'll pretend that the Psat is being set to 3.0 times the optical power,
# overloading whatever Psat_method is in the yaml file.

# %%
# !ls yamls
# Out:
# CHLAT_20230122.yaml SAT_20230122.yaml   SPLAT_20230122.yaml

# %%
yamlfile = 'yamls/SPLAT_20230122.yaml'
sim = yaml.safe_load(open(yamlfile))

# Overload whatever is in the yaml file, to set psats based on optical power.
sim['bolo_config']['psat_method'] = 'from_optical_power'
sim['bolo_config']['psat_factor'] = 3.0
    
# You can change the site or pwv if you want 
sim['sources']['atmosphere']['site'] = 'Pole' #Pole
sim['sources']['atmosphere']['pwv']  = 321  # 321

chlist = list(sim['channels'].keys())

# The bands in the yaml file are flat bands;  let's use the edges to determine
# the default band center and width, and then vary those by +- 10% in band center and width.
# This will create a 2D array of input (center,width) parameters, and we'll calculate
# P_optical and NET for each point in the 2D space.
#
nbins = 20
center_scalefactor = np.linspace(0.9,1.1,nbins)
width_scalefactor = np.linspace(0.7,1.3,nbins)

# set our logistic model parameters
a = 2.0
n = 0.7
#a = 10.0
#n = 0.9
plottitle= sim['sources']['atmosphere']['site']+', pvw='+str(sim['sources']['atmosphere']['pwv'])+',a='+str(a)+', n='+str(n)
print(plottitle)

out_NET = {}
out_NETrj = {}
out_Popt = {}
out_center = {}
out_width = {}

for ch in chlist:
    out_NET[ch] = np.empty((nbins,nbins))
    out_NETrj[ch] = np.empty((nbins,nbins))
    out_Popt[ch]= np.empty((nbins,nbins))
    out_center[ch]= np.empty((nbins,nbins))
    out_width[ch]= np.empty((nbins,nbins))
    
    # Save the low and high edges, and extend frequency coverage for "soft" bands,
    # so that integrals will be done over an extended range.
    sim['channels'][ch]['nu_low_0']  = sim['channels'][ch]['nu_low']
    sim['channels'][ch]['nu_high_0'] = sim['channels'][ch]['nu_high']
    sim['channels'][ch]['nu_center'] = (sim['channels'][ch]['nu_high_0'] + sim['channels'][ch]['nu_low_0'])/2.0
    sim['channels'][ch]['nu_width']  = sim['channels'][ch]['nu_high_0'] - sim['channels'][ch]['nu_low_0']
    sim['channels'][ch]['nu_low'] *= 0.5
    sim['channels'][ch]['nu_high'] *= 1.5
    
cc = 0
for cf in center_scalefactor:
    ww = 0
    for wf in width_scalefactor:
        if 'outputs' in sim.keys():  
            sim['outputs'].clear()  # Clear previous iteration results so things don't multiply.
        for ch in chlist:
            sim['channels'][ch]['band_response']['method']='band_vector'
            sim['channels'][ch]['band_response']['nuband_in'] = np.linspace(sim['channels'][ch]['nu_low'], sim['channels'][ch]['nu_high'], 1000)
            _outwidth  = wf*sim['channels'][ch]['nu_width']
            _outcenter = cf*sim['channels'][ch]['nu_center']
            sim['channels'][ch]['band_response']['band_in'] = logistic_bandmodel(sim['channels'][ch]['band_response']['nuband_in'], _outcenter, _outwidth,a,n)
            out_center[ch][ww][cc] = _outcenter
            out_width[ch][ww][cc]  = _outwidth
            
        # this runs on all channels
        run_optics(sim)
        run_bolos(sim)
        
        for ch in chlist:
            out_NET[ch][ww][cc] = sim['outputs'][ch]['NET_NC_total']
            out_NETrj[ch][ww][cc] = sim['outputs'][ch]['NETrj_NC_total']
            out_Popt[ch][ww][cc]= sim['outputs'][ch]['P_opt']

        ww += 1
    cc += 1
# Out:
# Pole, pvw=321,a=2.0, n=0.7

# %%
print(out_NET['LF_1'][int(nbins/2)][int(nbins/2)])
print(center_scalefactor[int(nbins/2)+1])
# Out:
# 0.000306861792783411
# 1.0157894736842106

# %%
# Plot the data calculated above

plt.rcParams['figure.figsize'] = [16, 16]

def pltnet(ch,rownum,colnum):
    netarr = 1e6*out_NET[ch]
    midpix = int(netarr.shape[0]/2)
    minval = 0.5*netarr[midpix][midpix]
    maxval = 2.0*netarr[midpix][midpix]
    if (maxval > np.max(netarr)):
        maxval = np.max(netarr)
    abc= axs[rownum,colnum].imshow(netarr,interpolation='bilinear',vmin = minval, vmax=maxval,cmap='rainbow',origin='lower',aspect='auto',extent=(np.min(out_center[ch]),np.max(out_center[ch]),np.min(out_width[ch]),np.max(out_width[ch])))
    axs[rownum,colnum].text(0.05, 0.8, ch, horizontalalignment='left',verticalalignment='center', transform=axs[rownum,colnum].transAxes)
    divider = make_axes_locatable(axs[rownum,colnum])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    axs[rownum,colnum].scatter(sim['channels'][ch]['nu_center'],sim['channels'][ch]['nu_width'],s=200,marker='x',c='m')
    fig.colorbar(abc, cax=cax, orientation='vertical')
    
def pltnetrj(ch,rownum,colnum):
    netarr = 1e6*out_NETrj[ch]
    midpix = int(netarr.shape[0]/2)
    minval = 0.5*netarr[midpix][midpix]
    maxval = 2.0*netarr[midpix][midpix]
    if (maxval > np.max(netarr)):
        maxval = np.max(netarr)
    abc= axs[rownum,colnum].imshow(netarr,interpolation='bilinear',vmin = minval, vmax=maxval,cmap='rainbow',origin='lower',aspect='auto',extent=(np.min(out_center[ch]),np.max(out_center[ch]),np.min(out_width[ch]),np.max(out_width[ch])))
    axs[rownum,colnum].text(0.05, 0.8, ch, horizontalalignment='left',verticalalignment='center', transform=axs[rownum,colnum].transAxes)
    divider = make_axes_locatable(axs[rownum,colnum])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    axs[rownum,colnum].scatter(sim['channels'][ch]['nu_center'],sim['channels'][ch]['nu_width'],s=200,marker='x',c='m')
    fig.colorbar(abc, cax=cax, orientation='vertical')
    
def pltpopt(ch,rownum,colnum):
    poptarr = 1e12*out_Popt[ch]
    midpix = int(poptarr.shape[0]/2)
    minval = 0.5*poptarr[midpix][midpix]
    maxval = 2.0*poptarr[midpix][midpix]
    if (maxval > np.max(poptarr)):
        maxval = np.max(poptarr)
    abc= axs[rownum,colnum].imshow(poptarr,vmin = minval, interpolation='bilinear',vmax=maxval,cmap='rainbow',origin='lower',aspect='auto',extent=(np.min(out_center[ch]),np.max(out_center[ch]),np.min(out_width[ch]),np.max(out_width[ch])))
    axs[rownum,colnum].text(0.05, 0.8, ch, horizontalalignment='left',verticalalignment='center', transform=axs[rownum,colnum].transAxes)
    divider = make_axes_locatable(axs[rownum,colnum])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    axs[rownum,colnum].scatter(sim['channels'][ch]['nu_center'],sim['channels'][ch]['nu_width'],s=200,marker='x',c='m')
    fig.colorbar(abc, cax=cax, orientation='vertical')

def pltatm(ch,rownum,colnum):
    divider = make_axes_locatable(axs[rownum,colnum])
    nu = sim['outputs'][ch]['nu']
    Tb =sim['outputs'][ch]['sources']['atmosphere']['Tb_atmos']
    #
    axs[rownum,colnum].plot(nu,Tb/np.max(Tb),label='Tb_atmos')
    axs[rownum,colnum].text(0.05, 0.8, ch, horizontalalignment='left',verticalalignment='center', transform=axs[rownum,colnum].transAxes)
    #
    center = sim['channels'][ch]['nu_center']
    width = sim['channels'][ch]['nu_width']
    band = logistic_bandmodel(sim['outputs'][ch]['nu'], center, width,a,n)
    axs[rownum,colnum].plot(nu,band,label='Det band')
    #
    axs[rownum,colnum].plot(nu,band*Tb/np.max(band*Tb), label = 'band*Tb')
    #axs[rownum,colnum].legend(loc='upper right')
    axs[rownum,colnum].grid()
    

npl_x = 4
npl_y = len(chlist)

fig, axs = plt.subplots(nrows=npl_y,ncols=npl_x,constrained_layout=True)
fig.set_constrained_layout_pads(w_pad=2 / 72, h_pad=2 / 72, hspace=0.1,
                                wspace=0.1)
rownum = 0
for ch in chlist:
    colnum = 0
    pltnet(ch,rownum,colnum)
    colnum = 1
    pltnetrj(ch,rownum,colnum)
    colnum = 2
    pltpopt(ch,rownum,colnum)
    colnum = 3
    pltatm(ch,rownum,colnum)
    rownum += 1
    
axs[0,0].set_title('NET (uKrtsec)')
axs[0,1].set_title('NET_RJ (uKrtsec)')
for jj in range(len(chlist)):
    axs[jj,0].set_ylabel('width (GHz)')
axs[0,2].set_title('P_optical (pW)')
axs[0,3].legend(loc='upper right')
axs[npl_y-1,0].set_xlabel('Center (GHz)')
axs[npl_y-1,1].set_xlabel('Center (GHz)')
axs[npl_y-1,2].set_xlabel('Frequency (GHz)')

fig.suptitle(plottitle)
# Out:
# Text(0.5, 0.98, 'Pole, pvw=321,a=2.0, n=0.7')

# %%
out_NET['LF_1'].shape
# Out:
# (20, 20)

# %% [markdown]
# # NET vs band wings
# Next, we'll look at the impact of band wings vs center and width, by varying
# the logistic function input parameter "a".

# %%
yamlfile = 'yamls/SPLAT_20230122.yaml'
sim = yaml.safe_load(open(yamlfile))

# Overload whatever is in the yaml file, to set psats based on optical power.
sim['bolo_config']['psat_method'] = 'from_optical_power'
sim['bolo_config']['psat_factor'] = 2.5
    
# You can change the site or pwv if you want 
sim['sources']['atmosphere']['site'] = 'Pole' #Pole
sim['sources']['atmosphere']['pwv']  = 321  # 321

# Set logistic function parameters
nbins = 10
a_vec = np.logspace(0.0, 1.0,nbins)
n = 0.7


chlist = list(sim['channels'].keys())

plottitle= sim['sources']['atmosphere']['site']+', pvw='+str(sim['sources']['atmosphere']['pwv'])+',a='+str(a)+', n='+str(n)
print(plottitle)

out_NET = {}
out_Popt = {}
out_center = {}
out_width = {}
out_wing = {}

# set up 
for ch in chlist:
    out_NET[ch]   = np.empty(nbins)
    out_Popt[ch]  = np.empty(nbins)
    out_center[ch]   = np.empty(nbins)
    out_width[ch]  = np.empty(nbins) 
    out_wing[ch]  = np.empty(nbins) 
    
    # Save the low and high edges, and extend frequency coverage for "soft" bands,
    # so that integrals will be done over an extended range.
    sim['channels'][ch]['nu_low_0']  = sim['channels'][ch]['nu_low']
    sim['channels'][ch]['nu_high_0'] = sim['channels'][ch]['nu_high']
    sim['channels'][ch]['nu_center'] = (sim['channels'][ch]['nu_high_0'] + sim['channels'][ch]['nu_low_0'])/2.0
    sim['channels'][ch]['nu_width']  = sim['channels'][ch]['nu_high_0'] - sim['channels'][ch]['nu_low_0']
    sim['channels'][ch]['nu_low'] *= 0.5
    sim['channels'][ch]['nu_high'] *= 1.5

ii = 0
for a in a_vec:
    if 'outputs' in sim.keys():  
        sim['outputs'].clear()  # Clear previous iteration results so things don't multiply.
    for ch in chlist:
        sim['channels'][ch]['band_response']['method']='band_vector'
        sim['channels'][ch]['band_response']['nuband_in'] = np.linspace(sim['channels'][ch]['nu_low'], sim['channels'][ch]['nu_high'], 1000)
        _width  = sim['channels'][ch]['nu_width']
        _center = sim['channels'][ch]['nu_center']
        _bandmodel = logistic_bandmodel(sim['channels'][ch]['band_response']['nuband_in'], _center, _width,a,n)
        sim['channels'][ch]['band_response']['band_in'] = _bandmodel
        
        _bandint = np.trapz(_bandmodel)
        _wing_h = np.trapz(np.where(_bandmodel>0.5,_bandmodel,0))
        _wing_l = np.trapz(np.where(_bandmodel>0.5,_bandmodel,0))
        out_center[ch][ii] = _center
        out_width[ch][ii]  = _width

    # this runs on all channels
    run_optics(sim)
    run_bolos(sim)

    for ch in chlist:
        out_NET[ch][ii] = sim['outputs'][ch]['NET_NC_total']
        out_Popt[ch][ii]= sim['outputs'][ch]['P_opt']

    ii += 1
# Out:
# Pole, pvw=321,a=2.0, n=0.7

# %%
plt.rcParams['figure.figsize'] = [8, 6]
for ch in chlist:
    plt.plot(a_vec,out_NET[ch]/out_NET[ch][-1],label=ch)
plt.ylabel('NET_cmb/NET_cmb(squarest)')
plt.xlabel('a')
plt.legend()   
plt.grid()

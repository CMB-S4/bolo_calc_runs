# %% [markdown]
# ## Run default configurations
# Print out Psats, NET, NET_wafer

# %%
import glob

# %%
# See what yaml files are locally available.
glob.glob('*.yaml')
# Out:
# ['CHLAT_20210714.yaml',
#  'SAT_HF_20220526.yaml',
#  'SAT_LF_20220526.yaml',
#  'SAT_MF_20220526.yaml',
#  'SPLAT_20210714.yaml']

# %%
# Standard imports
import numpy as np
import yaml
import toml
import pprint
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline  
plt.rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 20]

# bolo-calc import
from bolo import Top

# %%
def print_cam_tables(cam_tables):
    for keyname in cam_tables.keys():
        if 'cam' in keyname:
            print(keyname)
            dat = np.array(cam_tables[keyname])
            print('  Efficiency:         {0:3.2f}'.format(dat[0][0]))
            print('  Optical power (pW): {0:3.2f}'.format(dat[0][1]))
            print('  P_sat (pW):         {0:3.2f}'.format(dat[0][2]))
            print('  F_link:             {0:3.2f}'.format(dat[0][3]))
            print('  G:                  {0:3.2f}'.format(dat[0][4]))
            print('  NEP_bolo:           {0:3.2f}'.format(dat[0][7]))
            print('  NEP_readout:        {0:3.2f}'.format(dat[0][8]))       
            print('  NEP_photon:         {0:3.2f}'.format(dat[0][9]))
            print('  NEP_tot:            {0:3.2f}'.format(dat[0][10]))
            print('  NET_bolo:           {0:3.2f}'.format(dat[0][11]))
            print('  NET_bolo_corr:      {0:3.2f}'.format(dat[0][12]))
            print('  corr_factor:        {0:3.2f}'.format(dat[0][13]))
            print('  NET_wafer (uncorr)  {0:3.2f}'.format(dat[0][14]))
        print()

# %%
def print_optical_tables(cam_tables):
    chnames = []
    for chan in cam_tables.keys():
        if chan.split('_')[0] == 'cam' :
            chname = chan.split('_')[2] + '_' + chan.split('_')[3]
            chnames.append(chname)
    
    dat = cam_tables['optical']
    ncams = len(chnames)
    nrows = int(len(dat['channel'])/ncams)

    for n in range(ncams):
        print(chnames[n])
        rows = n*nrows + np.arange(nrows)
        dat['element','elem_effic_mean','elem_power_to_det_mean', 'elem_power_from_sky_mean'][rows].pprint()
        print()

# %% [markdown]
# ## Run
# Read yaml files, run bolo_calc, store some outputs into dictionary called "data".
# Print some outputs to table.

# %%
data = {}
tops = {}

yamlfiles = ['SAT_LF_20220526.yaml','SAT_MF_20220526.yaml', 'SAT_HF_20220526.yaml' ]
#read fixed PSATs from .toml file
psat_dict = toml.load("FixedPsats.toml")

for yamlfile in yamlfiles:
    print(yamlfile)
    data[yamlfile] = {}
    dd = yaml.safe_load(open(yamlfile))
    version_date = str(dd['version']['date'])
    version_telescope = str(dd['version']['name'])
    print('{0:8s}  Popt(pW) Psat(pW)   NET    NET_wafer  corr_fact'.format(version_telescope))
    del dd['version']

    # location of atmosphere file
    dd['sim_config']['config_dir'] = '../scripts'
    
    ch_names = list(dd['instrument']['camera_config']['elements']['cam_1']['chan_config']['elements'].keys())
    
    #---------
    #convert to Watts
    for channel in ch_names:
        psat_dict[yamlfile.partition('.')[0]][channel] *= 1e-12

    #set psat factor to None & delete psat entry from channel default
    dd['instrument']['channel_default']['psat_factor'] = None
    del dd['instrument']['channel_default']['psat']

    #assign SI psat values at the channel level
    for channel in ch_names:
        dd['instrument']['camera_config']['elements']['cam_1']['chan_config']['elements'][channel]['psat'] = psat_dict[yamlfile.partition('.')[0]][channel]
    #---------
    
    # Save some of the defaults things
    data[yamlfile]['defaults']={}
    data[yamlfile]['defaults']['Yield']=dd['instrument']['channel_default']['Yield']
    data[yamlfile]['defaults']['Tc']=dd['instrument']['channel_default']['Tc']
    data[yamlfile]['defaults']['waist_factor']=dd['instrument']['channel_default']['waist_factor']
    data[yamlfile]['defaults']['read_frac']=dd['instrument']['channel_default']['read_frac']
    data[yamlfile]['defaults']['site']=dd['instrument']['site']
    data[yamlfile]['defaults']['elevation']=dd['instrument']['elevation']
    data[yamlfile]['defaults']['pwv']=dd['instrument']['pwv']

    top = Top(**dd)
    top.run()
    
    tops[yamlfile] = top
    
    for chan in top.instrument.tables.keys():
        if chan.split('_')[0] == 'cam' :
            chname = chan.split('_')[2] + '_' + chan.split('_')[3]
            data[yamlfile][chname] = {}
            
            # Extract the optics table
            dat = top.instrument.tables['optical']
            chans = list(top.instrument.tables.keys())
            try:
                chans.remove('optical')
            except ValueError:
                pass
            
            ncams = len(chans)
            nrows = int(len(dat['channel'])/ncams)
            
            n = chans.index(chan)
            rows = n*nrows + np.arange(nrows)
            data[yamlfile][chname]['optics'] = {}
            
            optics_output = ['elem_effic_mean','elem_power_to_det_mean', 'elem_power_from_sky_mean']
            for r in rows:
                data[yamlfile][chname]['optics'][dat['element'][r]] = {}
                for out in optics_output:
                    data[yamlfile][chname]['optics'][dat['element'][r]][out] = dat[out][r]

            #
            # Grab things we're going to print and give them short names and store them in the dictionary.
            popt = top.instrument.tables[chan]['opt_power'][0]
            data[yamlfile][chname]['popt'] = popt
            psat = top.instrument.tables[chan]['P_sat'][0]
            data[yamlfile][chname]['psat'] = psat
            net = top.instrument.tables[chan]['NET'][0]
            data[yamlfile][chname]['net'] = net
            netwafer = top.instrument.tables[chan]['NET_arr'][0]
            data[yamlfile][chname]['netwafer'] = netwafer
            #
            # Grab things we're not going to print and store them in the dictionary.
            data[yamlfile][chname]['effic'] = top.instrument.tables[chan]['effic'][0]
            data[yamlfile][chname]['nep_photon'] = top.instrument.tables[chan]['NEP_ph'][0]
            data[yamlfile][chname]['nep_phonon'] = top.instrument.tables[chan]['NEP_bolo'][0]
            data[yamlfile][chname]['nep_readout'] = top.instrument.tables[chan]['NEP_read'][0]
            data[yamlfile][chname]['Gdyn'] = top.instrument.tables[chan]['G'][0]
            corr_fact = top.instrument.tables[chan]['corr_fact'][0]
            data[yamlfile][chname]['corr_fact'] = corr_fact 
            data[yamlfile][chname]['bandcenter'] = dd['instrument']['camera_config']['elements']['cam_1']['chan_config']['elements'][chname]['band_center']
            data[yamlfile][chname]['fractional_bandwidth'] = dd['instrument']['camera_config']['elements']['cam_1']['chan_config']['elements'][chname]['fractional_bandwidth']
            dnu = 0.5*data[yamlfile][chname]['bandcenter']*data[yamlfile][chname]['fractional_bandwidth']
            data[yamlfile][chname]['band_lowedge'] = data[yamlfile][chname]['bandcenter'] - dnu
            data[yamlfile][chname]['band_highedge'] = data[yamlfile][chname]['bandcenter'] + dnu
            print('{0:5s} : {1:8.2f} {2:8.2f} {3:8.2f} {4:8.2f} {5:8.2f}'.format(chname,popt,psat,net,netwafer,corr_fact) )
    print(' ')
# Out:
# SAT_LF_20220526.yaml
# SAT_LF    Popt(pW) Psat(pW)   NET    NET_wafer  corr_fact
# LF_1  :     0.52     1.30   147.45    33.65     1.04
# LF_2  :     2.13     5.32   190.05    43.37     1.01
#
# SAT_MF_20220526.yaml
# SAT_MF    Popt(pW) Psat(pW)   NET    NET_wafer  corr_fact
# MF1_1 :     2.52     6.11   250.59    16.34     1.03
# MF1_2 :     2.97     7.54   213.28    13.91     1.00
# MF2_1 :     2.37     6.11   205.73    12.51     1.02
# MF2_2 :     3.06     7.54   223.96    13.62     1.00
#
# SAT_HF_20220526.yaml
# SAT_HF    Popt(pW) Psat(pW)   NET    NET_wafer  corr_fact
# HF_1  :     6.20    15.51   459.67    16.78     1.01
# HF_2  :     8.06    20.16  1126.74    41.13     1.00

# %%
for yamlfile in yamlfiles:
    print(yamlfile)
    print_cam_tables(tops[yamlfile].instrument.tables)
# Out:
# SAT_LF_20220526.yaml
# cam_1_LF_1_sims
#   Efficiency:         0.45
#   Optical power (pW): 0.52
#   P_sat (pW):         1.30
#   F_link:             0.52
#   G:                  36.47
#   NEP_bolo:           5.20
#   NEP_readout:        3.33
#   NEP_photon:         9.02
#   NEP_tot:            10.94
#   NET_bolo:           147.45
#   NET_bolo_corr:      152.85
#   corr_factor:        1.04
#   NET_wafer (uncorr)  33.65
#
# cam_1_LF_2_sims
#   Efficiency:         0.48
#   Optical power (pW): 2.13
#   P_sat (pW):         5.32
#   F_link:             0.52
#   G:                  149.33
#   NEP_bolo:           10.52
#   NEP_readout:        9.15
#   NEP_photon:         26.56
#   NEP_tot:            29.99
#   NET_bolo:           190.05
#   NET_bolo_corr:      191.40
#   corr_factor:        1.01
#   NET_wafer (uncorr)  43.37
#
#
# SAT_MF_20220526.yaml
# cam_1_MF1_1_sims
#   Efficiency:         0.41
#   Optical power (pW): 2.52
#   P_sat (pW):         6.11
#   F_link:             0.52
#   G:                  171.49
#   NEP_bolo:           11.27
#   NEP_readout:        10.47
#   NEP_photon:         30.70
#   NEP_tot:            34.34
#   NET_bolo:           250.59
#   NET_bolo_corr:      258.45
#   corr_factor:        1.03
#   NET_wafer (uncorr)  16.34
#
# cam_1_MF1_2_sims
#   Efficiency:         0.47
#   Optical power (pW): 2.97
#   P_sat (pW):         7.54
#   F_link:             0.52
#   G:                  211.41
#   NEP_bolo:           12.52
#   NEP_readout:        11.47
#   NEP_photon:         33.55
#   NEP_tot:            37.60
#   NET_bolo:           213.28
#   NET_bolo_corr:      213.76
#   corr_factor:        1.00
#   NET_wafer (uncorr)  13.91
#
# cam_1_MF2_1_sims
#   Efficiency:         0.44
#   Optical power (pW): 2.37
#   P_sat (pW):         6.11
#   F_link:             0.52
#   G:                  171.49
#   NEP_bolo:           11.27
#   NEP_readout:        9.70
#   NEP_photon:         28.13
#   NEP_tot:            31.82
#   NET_bolo:           205.73
#   NET_bolo_corr:      209.85
#   corr_factor:        1.02
#   NET_wafer (uncorr)  12.51
#
# cam_1_MF2_2_sims
#   Efficiency:         0.46
#   Optical power (pW): 3.06
#   P_sat (pW):         7.54
#   F_link:             0.52
#   G:                  211.41
#   NEP_bolo:           12.52
#   NEP_readout:        11.73
#   NEP_photon:         34.43
#   NEP_tot:            38.47
#   NET_bolo:           223.96
#   NET_bolo_corr:      224.44
#   corr_factor:        1.00
#   NET_wafer (uncorr)  13.62
#
#
# SAT_HF_20220526.yaml
# cam_1_HF_1_sims
#   Efficiency:         0.39
#   Optical power (pW): 6.20
#   P_sat (pW):         15.51
#   F_link:             0.52
#   G:                  435.00
#   NEP_bolo:           17.95
#   NEP_readout:        19.08
#   NEP_photon:         56.84
#   NEP_tot:            62.59
#   NET_bolo:           459.67
#   NET_bolo_corr:      462.27
#   corr_factor:        1.01
#   NET_wafer (uncorr)  16.78
#
# cam_1_HF_2_sims
#   Efficiency:         0.36
#   Optical power (pW): 8.06
#   P_sat (pW):         20.16
#   F_link:             0.52
#   G:                  565.59
#   NEP_bolo:           20.47
#   NEP_readout:        24.24
#   NEP_photon:         72.90
#   NEP_tot:            79.51
#   NET_bolo:           1126.74
#   NET_bolo_corr:      1127.79
#   corr_factor:        1.00
#   NET_wafer (uncorr)  41.13

# %%
for t, top in tops.items():
    print_optical_tables(top.instrument.tables)
# Out:
# LF_1
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0    0.11492820524768763                      0.0
#         dust                1.0 4.2279542310596077e-17    9.300450289992005e-17
#  synchrotron                1.0  4.461159061563834e-12    9.802741156029342e-12
#   atmosphere 0.9839788328922576     0.1962565144760821       0.4246866653914209
#       baffle 0.9900000000000009    0.14917791835522756       0.7322575442602343
#       window 0.9895112525670474   0.007441669995524475       0.7405525536708778
#     RTMLI_10 0.9960100000000014    0.03312186412234843       0.8019751987877535
# alumina_filt 0.9750937898974739   0.014087172567808766        0.827661218118418
#   nylon_filt 0.9897030000000013  5.897877980019029e-05       0.8071481382769956
#        lens1 0.9754285204279718   0.000138736507520086       0.7991098096895228
#       ApStop 0.8699999999999991   0.004474287791867419       0.7870057809016217
#        lens2 0.9761488998301033 0.00013762154596132627       0.6848971014753896
#      lowpass             0.9405  6.612144468996746e-09       0.6685514505751315
#     detector 0.6300000000000001                    0.0       0.6287726392659114
#
# LF_2
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0     0.2210022181556197                      0.0
#         dust                1.0 1.6644571403855152e-16    3.490217001792531e-16
#  synchrotron                1.0 3.0244207872187463e-12     6.23105331726092e-12
#   atmosphere 0.9483466513516917     1.4200940638068498        2.811238630738357
#       baffle  0.989999999999998    0.33619708317639246       3.2420203887257184
#       window 0.9892646009574056   0.025234361731780664       3.2579793543670514
#     RTMLI_10 0.9960099999999976    0.07459413482968198       3.3651639686632655
# alumina_filt 0.9726265113494645   0.047585209370127175        3.440640632221761
#   nylon_filt  0.989306999999998  0.0002867729968673285       3.3457361215237227
#        lens1 0.9731289607115077 0.00031878216582501934        3.310529553629862
#       ApStop 0.9300000000000008  0.0034934105583683244        3.226171875018441
#        lens2 0.9742105956051704 0.00029645331175863704       3.0007908339604765
#      lowpass 0.9404999999999981 1.6126614018598114e-10       2.9225593324804606
#     detector 0.6500000000000016                    0.0       2.7486670521978738
#
# MF1_1
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0      0.137085560943348                      0.0
#         dust                1.0  5.144685120343637e-16    1.241422223238937e-15
#  synchrotron                1.0 2.6254659591278436e-13    6.385859567089614e-13
#   atmosphere 0.9354148607843137     1.8045818873735777        4.076136258289139
#       baffle               0.99     0.3409206161480508        4.495169585139189
#       window 0.9883875777951296    0.05616425879020632        4.573266001143511
#     RTMLI_10            0.99601    0.07545606072257593        4.684631064868802
# alumina_filt 0.9638980922470781    0.10451017714539092        4.887076235046447
#   nylon_filt           0.984456  0.0017368404478780167        4.715314047031173
#        lens1  0.964990737046674 0.00015112351781404378        4.642319379311013
#       ApStop              0.838   0.001936371452827458        4.483996552138529
#        lens2 0.9673451734541129  0.0001571583959523795        3.757804542313251
#      lowpass             0.9405 1.7692497521119675e-19        3.635809278110868
#     detector               0.65                    0.0       3.4194786260632712
#
# MF1_2
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0    0.12330728317431963                      0.0
#         dust                1.0 1.8997934988378984e-15     4.00418425623575e-15
#  synchrotron                1.0  9.478731286018228e-14   2.0383504417424254e-13
#   atmosphere 0.9659651255094044     1.6473680879269514       3.3513727388103325
#       baffle               0.99     0.5889301205288905        4.378894478959794
#       window 0.9872509834747717     0.1655850837988279        4.661414559536702
#     RTMLI_10            0.99601     0.1299298644418137        4.856301496662398
# alumina_filt 0.9526920485527272    0.30273408190145323        5.406382592281814
#   nylon_filt          0.9679923   0.007955413860287485        5.165179615247335
#        lens1  0.954534978076424  4.543406671287456e-05         4.99993079440638
#       ApStop              0.935 0.00012443174297583343        4.773430441740237
#        lens2 0.9585111541181772 4.2759428346779774e-05       4.4632199768112555
#      lowpass             0.9405 1.5545343245776675e-30        4.278530632215163
#     detector               0.68                    0.0         4.02395805959836
#
# MF2_1
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0     0.1451030494109709                      0.0
#         dust                1.0   7.06677154429609e-16     1.61867301251183e-15
#  synchrotron                1.0  2.228659642664501e-13    5.118472529843581e-13
#   atmosphere 0.9526277763157894      1.529055678006121        3.335372439868789
#       baffle               0.99     0.3945725698887584        3.987512184344752
#       window 0.9881980546310497    0.07265523099015334        4.101189917272162
#     RTMLI_10            0.99601     0.0872842323394073        4.236154075065555
# alumina_filt 0.9620213115897785    0.13480141538229418       4.4938655715359355
#   nylon_filt 0.9825750000000002  0.0025216849239333736        4.328152098123154
#        lens1  0.963240195309819  0.0001357945719933385        4.252992257287599
#       ApStop              0.875  0.0011539466007533085        4.098615960673919
#        lens2  0.965867206281993 0.00013546515019997608       3.5864828591919777
#      lowpass             0.9405 2.8882226641758637e-21         3.46412813421019
#     detector               0.65                    0.0        3.258012510224684
#
# MF2_2
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0     0.1140448146001862                      0.0
#         dust                1.0  2.161608146246925e-15    4.669592912292079e-15
#  synchrotron                1.0  8.112732134104877e-14   1.7954757713722409e-13
#   atmosphere 0.9669287996700879     1.6698406847374025        3.487235330629191
#       baffle               0.99     0.6134933706138768         4.59431593995236
#       window 0.9870616788804638    0.18440031041305663        4.920875736047116
#     RTMLI_10            0.99601    0.13527627454237565        5.128434474581009
# alumina_filt 0.9508371493823903    0.33613475677558974        5.754851782826027
#   nylon_filt           0.963765   0.009217847185076728        5.487666245379956
#        lens1 0.9528034579628321 3.4068486104533504e-05        5.288878875073921
#       ApStop              0.921 0.00010798467053081983        5.038956663685349
#        lens2 0.9570467227971952   3.26021583648222e-05        4.640926037543249
#      lowpass             0.9405 2.3175610582097604e-32        4.441244129264871
#     detector               0.68                    0.0        4.176990103573611
#
# HF_1
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0     0.0654620897105252                      0.0
#         dust                1.0  4.990484336357296e-15   1.2824445337370804e-14
#  synchrotron                1.0   3.74415388028833e-14   1.0853036648153524e-13
#   atmosphere 0.9464398800370454        3.9139851351311        9.517357570465178
#       baffle 0.9899999999999914      0.892929726482801       11.009161306799017
#       window  0.985699774576517    0.39318335388141773       11.822163299295974
#     RTMLI_10 0.9956499999999945    0.21390221460363903       12.150234472156164
# alumina_filt 0.9375897936799006     0.7016206543600143       13.643451018194707
#   nylon_filt 0.9208980000000017    0.02123664176528632       12.828723843666397
#        lens1 0.9404303977298041  4.188884841290197e-06       11.813953509936104
#       ApStop 0.8750000000000019  1.556913533678103e-05        11.10729438062464
#        lens2  0.946569734612986   4.26552073323377e-06        9.718888506111684
#      lowpass 0.9405000000000102 1.1954367078418617e-44        9.197633972432321
#     detector  0.670000000000006                    0.0          8.6503747510726
#
# HF_2
#   element     elem_effic_mean   elem_power_to_det_mean elem_power_from_sky_mean
# ------------ ------------------ ---------------------- ------------------------
#          cmb                1.0   0.027269353715990065                      0.0
#         dust                1.0    6.0761297147328e-15   1.6999791112780288e-14
#  synchrotron                1.0 1.7380908259902564e-14    6.536293781545307e-14
#   atmosphere 0.9218305635952218       5.46929774071369        14.10700100458683
#       baffle 0.9899999999999946     0.8518415118851766       14.955434923102114
#       window 0.9845945856821702     0.4720855216183431       15.979838520874058
#     RTMLI_10  0.991699999999989    0.38966317988593824       16.688247919661286
# alumina_filt 0.9269598671677649     0.8309593593130313       18.452132855335314
#   nylon_filt 0.8682299999999922   0.023336729582911567       17.141893192425364
#        lens1 0.9304935409035613 4.2772003374547945e-07       14.883106617718934
#       ApStop 0.9210000000000026  7.564357653050747e-07       13.844412363276394
#        lens2  0.938140153295315  4.178033828520193e-07       12.750704406487852
#      lowpass 0.9405000000000019 2.7449617792851584e-45       11.958972212428025
#     detector 0.6600000000000009                    0.0       11.247413365788558

# %% [markdown]
# ## Make a 4-panel plot.
# Popt, Psat, NET, NET_wafer

# %%
# Plot things vs frequency for each telescope

# Set up a 4-panel plot
plt.clf()
ax1=plt.subplot(4,1,1)
ax1.set_ylabel('P_opt')
ax1.set_xlim(0,300)
ax1.set_ylim(0.1,70)
ax1.grid()
#
ax2=plt.subplot(4,1,2)
ax2.set_ylabel('P_sat')
ax2.set_xlim(0,300)
ax2.set_ylim(0.1,70)
ax2.grid()
#
ax3=plt.subplot(4,1,3)
ax3.set_ylabel('Single Detector NET')
ax3.set_xlim(0,300)
ax3.grid()
#
ax4=plt.subplot(4,1,4)
ax4.set_ylabel('NET_wafer')
ax4.set_xlim(0,300)
ax4.grid()
yfrac = 0.7

for yamlfile in yamlfiles: 
    telescope = yamlfile.split('_')[0]
    if telescope == 'CHLAT':
        pointtype = '.r'
    elif telescope == 'SPLAT':
        pointtype = '.b'
    else:
        pointtype = '+m'
    
    for chname in data[yamlfile].keys():
        if chname != 'defaults':
            nu = data[yamlfile][chname]['bandcenter']
            #
            ax1.semilogy(nu, data[yamlfile][chname]['popt'],pointtype, markersize=15 )
            ax2.semilogy(nu, data[yamlfile][chname]['psat'],pointtype, markersize=15 )
            ax3.plot(nu, data[yamlfile][chname]['net'],pointtype, markersize=15 )
            ax4.plot(nu, data[yamlfile][chname]['netwafer'],pointtype, markersize=15 )
            #
    
    ymin,ymax = ax1.set_ylim()
    xmin,xmax = ax1.set_xlim()
    xval = xmin+0.05*(xmax-xmin)
    yval = ymin+yfrac*(ymax-ymin)
    ax1.semilogy(xval, yval, pointtype, markersize=15)
    ax1.text(xval+0.05*(xmax-xmin), yval, telescope, verticalalignment='center')
    yfrac = yfrac*0.6


ax1.grid()
ax1.grid()
ax1.set_title(version_date)
# Out:
# Text(0.5, 1.0, '20220524')

# %% [markdown]
# ## Make a 4-panel plot.
# efficiency, NEP_photon, NEP_phonon, NEP_readout

# %%
plt.clf()
ax1=plt.subplot(4,1,1)
ax1.set_ylabel('Effic.')
ax1.set_xlim(0,300)
ax1.set_ylim(0,0.7)
ax1.grid()
#
ax2=plt.subplot(4,1,2)
ax2.set_ylabel('NEP_photon')
ax2.set_xlim(0,300)
ax2.set_ylim(1,200)
ax2.grid()
#
ax3=plt.subplot(4,1,3)
ax3.set_ylabel('NEP_phonon')
ax3.set_xlim(0,300)
ax3.set_ylim(1,200)
ax3.grid()
#
ax4=plt.subplot(4,1,4)
ax4.set_ylabel('NEP_readout')
ax4.set_xlim(0,300)
ax4.set_ylim(1,200)
ax4.grid()

#data = {}
yfrac = 0.3

for yamlfile in yamlfiles: 
    telescope = yamlfile.split('_')[0]
    if telescope == 'CHLAT':
        pointtype = '.r'
    elif telescope == 'SPLAT':
        pointtype = '.b'
    else:
        pointtype = '+m'
    
    for chname in data[yamlfile].keys():
        if chname != 'defaults':
            nu = data[yamlfile][chname]['bandcenter']
            #
            ax1.plot(nu, data[yamlfile][chname]['effic'],pointtype, markersize=15 )
            ax2.semilogy(nu, data[yamlfile][chname]['nep_photon'],pointtype, markersize=15 )
            ax3.semilogy(nu, data[yamlfile][chname]['nep_phonon'],pointtype, markersize=15 )
            ax4.semilogy(nu, data[yamlfile][chname]['nep_readout'],pointtype, markersize=15 )

    
    ymin,ymax = ax1.set_ylim()
    xmin,xmax = ax1.set_xlim()
    xval = xmin+0.7*(xmax-xmin)
    yval = ymin+yfrac*(ymax-ymin)
    ax1.plot(xval,yval,pointtype,markersize=15)
    ax1.text(xval+0.05*(xmax-xmin),yval,telescope,verticalalignment='center')
    yfrac = yfrac-0.1


ax1.grid()
ax1.grid()
ax1.set_title(version_date)
# Out:
# Text(0.5, 1.0, '20220524')

# %%
# Write to files
data['runtime'] = datetime.today().strftime('%Y/%m/%d %H:%M:%S')
data['input_id'] = version_date
data['variation'] = 'BaseModel'

# Write to toml file
output_file_name = data['variation'] + '.toml'
with open('outputs/' + output_file_name, "w") as toml_file:
    toml.dump(data, toml_file, encoder=toml.TomlNumpyEncoder())

# %% [markdown]
# # Explore data

# %%
pprint.pprint(data)
# Out:
# {'SAT_HF_20220526.yaml': {'HF_1': {'Gdyn': 435.00362431996723,
#                                    'band_highedge': 256.056,
#                                    'band_lowedge': 197.944,
#                                    'bandcenter': 227.0,
#                                    'corr_fact': 1.0056538194910032,
#                                    'effic': 0.38973549936900687,
#                                    'fractional_bandwidth': 0.256,
#                                    'nep_phonon': 17.952170291052735,
#                                    'nep_photon': 56.837430396823564,
#                                    'nep_readout': 19.082959047484067,
#                                    'net': 459.67157758761266,
#                                    'netwafer': 16.780358640086675,
#                                    'optics': {'ApStop': {'elem_effic_mean': 0.8750000000000019,
#                                                          'elem_power_from_sky_mean': 11.10729438062464,
#                                                          'elem_power_to_det_mean': 1.556913533678103e-05},
#                                               'RTMLI_10': {'elem_effic_mean': 0.9956499999999945,
#                                                            'elem_power_from_sky_mean': 12.150234472156164,
#                                                            'elem_power_to_det_mean': 0.21390221460363903},
#                                               'alumina_filt': {'elem_effic_mean': 0.9375897936799006,
#                                                                'elem_power_from_sky_mean': 13.643451018194707,
#                                                                'elem_power_to_det_mean': 0.7016206543600143},
#                                               'atmosphere': {'elem_effic_mean': 0.9464398800370454,
#                                                              'elem_power_from_sky_mean': 9.517357570465178,
#                                                              'elem_power_to_det_mean': 3.9139851351311},
#                                               'baffle': {'elem_effic_mean': 0.9899999999999914,
#                                                          'elem_power_from_sky_mean': 11.009161306799017,
#                                                          'elem_power_to_det_mean': 0.892929726482801},
#                                               'cmb': {'elem_effic_mean': 1.0,
#                                                       'elem_power_from_sky_mean': 0.0,
#                                                       'elem_power_to_det_mean': 0.0654620897105252},
#                                               'detector': {'elem_effic_mean': 0.670000000000006,
#                                                            'elem_power_from_sky_mean': 8.6503747510726,
#                                                            'elem_power_to_det_mean': 0.0},
#                                               'dust': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 1.2824445337370804e-14,
#                                                        'elem_power_to_det_mean': 4.990484336357296e-15},
#                                               'lens1': {'elem_effic_mean': 0.9404303977298041,
#                                                         'elem_power_from_sky_mean': 11.813953509936104,
#                                                         'elem_power_to_det_mean': 4.188884841290197e-06},
#                                               'lens2': {'elem_effic_mean': 0.946569734612986,
#                                                         'elem_power_from_sky_mean': 9.718888506111684,
#                                                         'elem_power_to_det_mean': 4.26552073323377e-06},
#                                               'lowpass': {'elem_effic_mean': 0.9405000000000102,
#                                                           'elem_power_from_sky_mean': 9.197633972432321,
#                                                           'elem_power_to_det_mean': 1.1954367078418617e-44},
#                                               'nylon_filt': {'elem_effic_mean': 0.9208980000000017,
#                                                              'elem_power_from_sky_mean': 12.828723843666397,
#                                                              'elem_power_to_det_mean': 0.02123664176528632},
#                                               'synchrotron': {'elem_effic_mean': 1.0,
#                                                               'elem_power_from_sky_mean': 1.0853036648153524e-13,
#                                                               'elem_power_to_det_mean': 3.74415388028833e-14},
#                                               'window': {'elem_effic_mean': 0.985699774576517,
#                                                          'elem_power_from_sky_mean': 11.822163299295974,
#                                                          'elem_power_to_det_mean': 0.39318335388141773}},
#                                    'popt': 6.202343839475736,
#                                    'psat': 15.506000000000002},
#                           'HF_2': {'Gdyn': 565.5944840651914,
#                                    'band_highedge': 315.04925,
#                                    'band_lowedge': 255.95075,
#                                    'bandcenter': 285.5,
#                                    'corr_fact': 1.00093235342694,
#                                    'effic': 0.35795559058412857,
#                                    'fractional_bandwidth': 0.207,
#                                    'nep_phonon': 20.47024799979572,
#                                    'nep_photon': 72.90496203732015,
#                                    'nep_readout': 24.243594321814456,
#                                    'net': 1126.742077960393,
#                                    'netwafer': 41.13183647829134,
#                                    'optics': {'ApStop': {'elem_effic_mean': 0.9210000000000026,
#                                                          'elem_power_from_sky_mean': 13.844412363276394,
#                                                          'elem_power_to_det_mean': 7.564357653050747e-07},
#                                               'RTMLI_10': {'elem_effic_mean': 0.991699999999989,
#                                                            'elem_power_from_sky_mean': 16.688247919661286,
#                                                            'elem_power_to_det_mean': 0.38966317988593824},
#                                               'alumina_filt': {'elem_effic_mean': 0.9269598671677649,
#                                                                'elem_power_from_sky_mean': 18.452132855335314,
#                                                                'elem_power_to_det_mean': 0.8309593593130313},
#                                               'atmosphere': {'elem_effic_mean': 0.9218305635952218,
#                                                              'elem_power_from_sky_mean': 14.10700100458683,
#                                                              'elem_power_to_det_mean': 5.46929774071369},
#                                               'baffle': {'elem_effic_mean': 0.9899999999999946,
#                                                          'elem_power_from_sky_mean': 14.955434923102114,
#                                                          'elem_power_to_det_mean': 0.8518415118851766},
#                                               'cmb': {'elem_effic_mean': 1.0,
#                                                       'elem_power_from_sky_mean': 0.0,
#                                                       'elem_power_to_det_mean': 0.027269353715990065},
#                                               'detector': {'elem_effic_mean': 0.6600000000000009,
#                                                            'elem_power_from_sky_mean': 11.247413365788558,
#                                                            'elem_power_to_det_mean': 0.0},
#                                               'dust': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 1.6999791112780288e-14,
#                                                        'elem_power_to_det_mean': 6.0761297147328e-15},
#                                               'lens1': {'elem_effic_mean': 0.9304935409035613,
#                                                         'elem_power_from_sky_mean': 14.883106617718934,
#                                                         'elem_power_to_det_mean': 4.2772003374547945e-07},
#                                               'lens2': {'elem_effic_mean': 0.938140153295315,
#                                                         'elem_power_from_sky_mean': 12.750704406487852,
#                                                         'elem_power_to_det_mean': 4.178033828520193e-07},
#                                               'lowpass': {'elem_effic_mean': 0.9405000000000019,
#                                                           'elem_power_from_sky_mean': 11.958972212428025,
#                                                           'elem_power_to_det_mean': 2.7449617792851584e-45},
#                                               'nylon_filt': {'elem_effic_mean': 0.8682299999999922,
#                                                              'elem_power_from_sky_mean': 17.141893192425364,
#                                                              'elem_power_to_det_mean': 0.023336729582911567},
#                                               'synchrotron': {'elem_effic_mean': 1.0,
#                                                               'elem_power_from_sky_mean': 6.536293781545307e-14,
#                                                               'elem_power_to_det_mean': 1.7380908259902564e-14},
#                                               'window': {'elem_effic_mean': 0.9845945856821702,
#                                                          'elem_power_from_sky_mean': 15.979838520874058,
#                                                          'elem_power_to_det_mean': 0.4720855216183431}},
#                                    'popt': 8.064454998674288,
#                                    'psat': 20.161},
#                           'defaults': {'Tc': 0.16,
#                                        'Yield': 0.8,
#                                        'elevation': 50.0,
#                                        'pwv': 321.0,
#                                        'read_frac': 0.05,
#                                        'site': 'Pole',
#                                        'waist_factor': 3.0}},
#  'SAT_LF_20220526.yaml': {'LF_1': {'Gdyn': 36.47005750135157,
#                                    'band_highedge': 29.99875,
#                                    'band_lowedge': 21.50125,
#                                    'bandcenter': 25.75,
#                                    'corr_fact': 1.036581160661388,
#                                    'effic': 0.4547658248144099,
#                                    'fractional_bandwidth': 0.33,
#                                    'nep_phonon': 5.1980295679774775,
#                                    'nep_photon': 9.024474557991201,
#                                    'nep_readout': 3.334249072105046,
#                                    'net': 147.4536699678197,
#                                    'netwafer': 33.65154217845704,
#                                    'optics': {'ApStop': {'elem_effic_mean': 0.8699999999999991,
#                                                          'elem_power_from_sky_mean': 0.7870057809016217,
#                                                          'elem_power_to_det_mean': 0.004474287791867419},
#                                               'RTMLI_10': {'elem_effic_mean': 0.9960100000000014,
#                                                            'elem_power_from_sky_mean': 0.8019751987877535,
#                                                            'elem_power_to_det_mean': 0.03312186412234843},
#                                               'alumina_filt': {'elem_effic_mean': 0.9750937898974739,
#                                                                'elem_power_from_sky_mean': 0.827661218118418,
#                                                                'elem_power_to_det_mean': 0.014087172567808766},
#                                               'atmosphere': {'elem_effic_mean': 0.9839788328922576,
#                                                              'elem_power_from_sky_mean': 0.4246866653914209,
#                                                              'elem_power_to_det_mean': 0.1962565144760821},
#                                               'baffle': {'elem_effic_mean': 0.9900000000000009,
#                                                          'elem_power_from_sky_mean': 0.7322575442602343,
#                                                          'elem_power_to_det_mean': 0.14917791835522756},
#                                               'cmb': {'elem_effic_mean': 1.0,
#                                                       'elem_power_from_sky_mean': 0.0,
#                                                       'elem_power_to_det_mean': 0.11492820524768763},
#                                               'detector': {'elem_effic_mean': 0.6300000000000001,
#                                                            'elem_power_from_sky_mean': 0.6287726392659114,
#                                                            'elem_power_to_det_mean': 0.0},
#                                               'dust': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 9.300450289992005e-17,
#                                                        'elem_power_to_det_mean': 4.2279542310596077e-17},
#                                               'lens1': {'elem_effic_mean': 0.9754285204279718,
#                                                         'elem_power_from_sky_mean': 0.7991098096895228,
#                                                         'elem_power_to_det_mean': 0.000138736507520086},
#                                               'lens2': {'elem_effic_mean': 0.9761488998301033,
#                                                         'elem_power_from_sky_mean': 0.6848971014753896,
#                                                         'elem_power_to_det_mean': 0.00013762154596132627},
#                                               'lowpass': {'elem_effic_mean': 0.9405,
#                                                           'elem_power_from_sky_mean': 0.6685514505751315,
#                                                           'elem_power_to_det_mean': 6.612144468996746e-09},
#                                               'nylon_filt': {'elem_effic_mean': 0.9897030000000013,
#                                                              'elem_power_from_sky_mean': 0.8071481382769956,
#                                                              'elem_power_to_det_mean': 5.897877980019029e-05},
#                                               'synchrotron': {'elem_effic_mean': 1.0,
#                                                               'elem_power_from_sky_mean': 9.802741156029342e-12,
#                                                               'elem_power_to_det_mean': 4.461159061563834e-12},
#                                               'window': {'elem_effic_mean': 0.9895112525670474,
#                                                          'elem_power_from_sky_mean': 0.7405525536708778,
#                                                          'elem_power_to_det_mean': 0.007441669995524475}},
#                                    'popt': 0.5198229760064338,
#                                    'psat': 1.3},
#                           'LF_2': {'Gdyn': 149.33085852284185,
#                                    'band_highedge': 47.5075,
#                                    'band_lowedge': 29.9925,
#                                    'bandcenter': 38.75,
#                                    'corr_fact': 1.0071015451921028,
#                                    'effic': 0.4798113083809886,
#                                    'fractional_bandwidth': 0.452,
#                                    'nep_phonon': 10.51829392156904,
#                                    'nep_photon': 26.557416945716287,
#                                    'nep_readout': 9.14510346795138,
#                                    'net': 190.0470850254625,
#                                    'netwafer': 43.37211477356169,
#                                    'optics': {'ApStop': {'elem_effic_mean': 0.9300000000000008,
#                                                          'elem_power_from_sky_mean': 3.226171875018441,
#                                                          'elem_power_to_det_mean': 0.0034934105583683244},
#                                               'RTMLI_10': {'elem_effic_mean': 0.9960099999999976,
#                                                            'elem_power_from_sky_mean': 3.3651639686632655,
#                                                            'elem_power_to_det_mean': 0.07459413482968198},
#                                               'alumina_filt': {'elem_effic_mean': 0.9726265113494645,
#                                                                'elem_power_from_sky_mean': 3.440640632221761,
#                                                                'elem_power_to_det_mean': 0.047585209370127175},
#                                               'atmosphere': {'elem_effic_mean': 0.9483466513516917,
#                                                              'elem_power_from_sky_mean': 2.811238630738357,
#                                                              'elem_power_to_det_mean': 1.4200940638068498},
#                                               'baffle': {'elem_effic_mean': 0.989999999999998,
#                                                          'elem_power_from_sky_mean': 3.2420203887257184,
#                                                          'elem_power_to_det_mean': 0.33619708317639246},
#                                               'cmb': {'elem_effic_mean': 1.0,
#                                                       'elem_power_from_sky_mean': 0.0,
#                                                       'elem_power_to_det_mean': 0.2210022181556197},
#                                               'detector': {'elem_effic_mean': 0.6500000000000016,
#                                                            'elem_power_from_sky_mean': 2.7486670521978738,
#                                                            'elem_power_to_det_mean': 0.0},
#                                               'dust': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 3.490217001792531e-16,
#                                                        'elem_power_to_det_mean': 1.6644571403855152e-16},
#                                               'lens1': {'elem_effic_mean': 0.9731289607115077,
#                                                         'elem_power_from_sky_mean': 3.310529553629862,
#                                                         'elem_power_to_det_mean': 0.00031878216582501934},
#                                               'lens2': {'elem_effic_mean': 0.9742105956051704,
#                                                         'elem_power_from_sky_mean': 3.0007908339604765,
#                                                         'elem_power_to_det_mean': 0.00029645331175863704},
#                                               'lowpass': {'elem_effic_mean': 0.9404999999999981,
#                                                           'elem_power_from_sky_mean': 2.9225593324804606,
#                                                           'elem_power_to_det_mean': 1.6126614018598114e-10},
#                                               'nylon_filt': {'elem_effic_mean': 0.989306999999998,
#                                                              'elem_power_from_sky_mean': 3.3457361215237227,
#                                                              'elem_power_to_det_mean': 0.0002867729968673285},
#                                               'synchrotron': {'elem_effic_mean': 1.0,
#                                                               'elem_power_from_sky_mean': 6.23105331726092e-12,
#                                                               'elem_power_to_det_mean': 3.0244207872187463e-12},
#                                               'window': {'elem_effic_mean': 0.9892646009574056,
#                                                          'elem_power_from_sky_mean': 3.2579793543670514,
#                                                          'elem_power_to_det_mean': 0.025234361731780664}},
#                                    'popt': 2.129102490267562,
#                                    'psat': 5.323},
#                           'defaults': {'Tc': 0.16,
#                                        'Yield': 0.8,
#                                        'elevation': 50.0,
#                                        'pwv': 321.0,
#                                        'read_frac': 0.05,
#                                        'site': 'Pole',
#                                        'waist_factor': 3.0}},
#  'SAT_MF_20220526.yaml': {'MF1_1': {'Gdyn': 171.49343192750933,
#                                     'band_highedge': 95.2,
#                                     'band_lowedge': 74.8,
#                                     'bandcenter': 85.0,
#                                     'corr_fact': 1.0313836754067982,
#                                     'effic': 0.4136652642474314,
#                                     'fractional_bandwidth': 0.24,
#                                     'nep_phonon': 11.271825772675937,
#                                     'nep_photon': 30.69742461312642,
#                                     'nep_readout': 10.469577749275972,
#                                     'net': 250.58891643111784,
#                                     'netwafer': 16.339666927392884,
#                                     'optics': {'ApStop': {'elem_effic_mean': 0.838,
#                                                           'elem_power_from_sky_mean': 4.483996552138529,
#                                                           'elem_power_to_det_mean': 0.001936371452827458},
#                                                'RTMLI_10': {'elem_effic_mean': 0.99601,
#                                                             'elem_power_from_sky_mean': 4.684631064868802,
#                                                             'elem_power_to_det_mean': 0.07545606072257593},
#                                                'alumina_filt': {'elem_effic_mean': 0.9638980922470781,
#                                                                 'elem_power_from_sky_mean': 4.887076235046447,
#                                                                 'elem_power_to_det_mean': 0.10451017714539092},
#                                                'atmosphere': {'elem_effic_mean': 0.9354148607843137,
#                                                               'elem_power_from_sky_mean': 4.076136258289139,
#                                                               'elem_power_to_det_mean': 1.8045818873735777},
#                                                'baffle': {'elem_effic_mean': 0.99,
#                                                           'elem_power_from_sky_mean': 4.495169585139189,
#                                                           'elem_power_to_det_mean': 0.3409206161480508},
#                                                'cmb': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 0.0,
#                                                        'elem_power_to_det_mean': 0.137085560943348},
#                                                'detector': {'elem_effic_mean': 0.65,
#                                                             'elem_power_from_sky_mean': 3.4194786260632712,
#                                                             'elem_power_to_det_mean': 0.0},
#                                                'dust': {'elem_effic_mean': 1.0,
#                                                         'elem_power_from_sky_mean': 1.241422223238937e-15,
#                                                         'elem_power_to_det_mean': 5.144685120343637e-16},
#                                                'lens1': {'elem_effic_mean': 0.964990737046674,
#                                                          'elem_power_from_sky_mean': 4.642319379311013,
#                                                          'elem_power_to_det_mean': 0.00015112351781404378},
#                                                'lens2': {'elem_effic_mean': 0.9673451734541129,
#                                                          'elem_power_from_sky_mean': 3.757804542313251,
#                                                          'elem_power_to_det_mean': 0.0001571583959523795},
#                                                'lowpass': {'elem_effic_mean': 0.9405,
#                                                            'elem_power_from_sky_mean': 3.635809278110868,
#                                                            'elem_power_to_det_mean': 1.7692497521119675e-19},
#                                                'nylon_filt': {'elem_effic_mean': 0.984456,
#                                                               'elem_power_from_sky_mean': 4.715314047031173,
#                                                               'elem_power_to_det_mean': 0.0017368404478780167},
#                                                'synchrotron': {'elem_effic_mean': 1.0,
#                                                                'elem_power_from_sky_mean': 6.385859567089614e-13,
#                                                                'elem_power_to_det_mean': 2.6254659591278436e-13},
#                                                'window': {'elem_effic_mean': 0.9883875777951296,
#                                                           'elem_power_from_sky_mean': 4.573266001143511,
#                                                           'elem_power_to_det_mean': 0.05616425879020632}},
#                                     'popt': 2.522700054937885,
#                                     'psat': 6.113},
#                           'MF1_2': {'Gdyn': 211.41411794629644,
#                                     'band_highedge': 160.95,
#                                     'band_lowedge': 129.05,
#                                     'bandcenter': 145.0,
#                                     'corr_fact': 1.0022765666702007,
#                                     'effic': 0.4744300299117225,
#                                     'fractional_bandwidth': 0.22,
#                                     'nep_phonon': 12.515191932262697,
#                                     'nep_photon': 33.55388423541209,
#                                     'nep_readout': 11.465406690538412,
#                                     'net': 213.27634775616616,
#                                     'netwafer': 13.906698410520063,
#                                     'optics': {'ApStop': {'elem_effic_mean': 0.935,
#                                                           'elem_power_from_sky_mean': 4.773430441740237,
#                                                           'elem_power_to_det_mean': 0.00012443174297583343},
#                                                'RTMLI_10': {'elem_effic_mean': 0.99601,
#                                                             'elem_power_from_sky_mean': 4.856301496662398,
#                                                             'elem_power_to_det_mean': 0.1299298644418137},
#                                                'alumina_filt': {'elem_effic_mean': 0.9526920485527272,
#                                                                 'elem_power_from_sky_mean': 5.406382592281814,
#                                                                 'elem_power_to_det_mean': 0.30273408190145323},
#                                                'atmosphere': {'elem_effic_mean': 0.9659651255094044,
#                                                               'elem_power_from_sky_mean': 3.3513727388103325,
#                                                               'elem_power_to_det_mean': 1.6473680879269514},
#                                                'baffle': {'elem_effic_mean': 0.99,
#                                                           'elem_power_from_sky_mean': 4.378894478959794,
#                                                           'elem_power_to_det_mean': 0.5889301205288905},
#                                                'cmb': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 0.0,
#                                                        'elem_power_to_det_mean': 0.12330728317431963},
#                                                'detector': {'elem_effic_mean': 0.68,
#                                                             'elem_power_from_sky_mean': 4.02395805959836,
#                                                             'elem_power_to_det_mean': 0.0},
#                                                'dust': {'elem_effic_mean': 1.0,
#                                                         'elem_power_from_sky_mean': 4.00418425623575e-15,
#                                                         'elem_power_to_det_mean': 1.8997934988378984e-15},
#                                                'lens1': {'elem_effic_mean': 0.954534978076424,
#                                                          'elem_power_from_sky_mean': 4.99993079440638,
#                                                          'elem_power_to_det_mean': 4.543406671287456e-05},
#                                                'lens2': {'elem_effic_mean': 0.9585111541181772,
#                                                          'elem_power_from_sky_mean': 4.4632199768112555,
#                                                          'elem_power_to_det_mean': 4.2759428346779774e-05},
#                                                'lowpass': {'elem_effic_mean': 0.9405,
#                                                            'elem_power_from_sky_mean': 4.278530632215163,
#                                                            'elem_power_to_det_mean': 1.5545343245776675e-30},
#                                                'nylon_filt': {'elem_effic_mean': 0.9679923,
#                                                               'elem_power_from_sky_mean': 5.165179615247335,
#                                                               'elem_power_to_det_mean': 0.007955413860287485},
#                                                'synchrotron': {'elem_effic_mean': 1.0,
#                                                                'elem_power_from_sky_mean': 2.0383504417424254e-13,
#                                                                'elem_power_to_det_mean': 9.478731286018228e-14},
#                                                'window': {'elem_effic_mean': 0.9872509834747717,
#                                                           'elem_power_from_sky_mean': 4.661414559536702,
#                                                           'elem_power_to_det_mean': 0.1655850837988279}},
#                                     'popt': 2.966022560870676,
#                                     'psat': 7.5360000000000005},
#                           'MF2_1': {'Gdyn': 171.49343192750933,
#                                     'band_highedge': 106.4,
#                                     'band_lowedge': 83.6,
#                                     'bandcenter': 95.0,
#                                     'corr_fact': 1.0200336904878198,
#                                     'effic': 0.43666486292389484,
#                                     'fractional_bandwidth': 0.24,
#                                     'nep_phonon': 11.271825772675937,
#                                     'nep_photon': 28.132214695214362,
#                                     'nep_readout': 9.702769959680982,
#                                     'net': 205.73263824187578,
#                                     'netwafer': 12.511225497688203,
#                                     'optics': {'ApStop': {'elem_effic_mean': 0.875,
#                                                           'elem_power_from_sky_mean': 4.098615960673919,
#                                                           'elem_power_to_det_mean': 0.0011539466007533085},
#                                                'RTMLI_10': {'elem_effic_mean': 0.99601,
#                                                             'elem_power_from_sky_mean': 4.236154075065555,
#                                                             'elem_power_to_det_mean': 0.0872842323394073},
#                                                'alumina_filt': {'elem_effic_mean': 0.9620213115897785,
#                                                                 'elem_power_from_sky_mean': 4.4938655715359355,
#                                                                 'elem_power_to_det_mean': 0.13480141538229418},
#                                                'atmosphere': {'elem_effic_mean': 0.9526277763157894,
#                                                               'elem_power_from_sky_mean': 3.335372439868789,
#                                                               'elem_power_to_det_mean': 1.529055678006121},
#                                                'baffle': {'elem_effic_mean': 0.99,
#                                                           'elem_power_from_sky_mean': 3.987512184344752,
#                                                           'elem_power_to_det_mean': 0.3945725698887584},
#                                                'cmb': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 0.0,
#                                                        'elem_power_to_det_mean': 0.1451030494109709},
#                                                'detector': {'elem_effic_mean': 0.65,
#                                                             'elem_power_from_sky_mean': 3.258012510224684,
#                                                             'elem_power_to_det_mean': 0.0},
#                                                'dust': {'elem_effic_mean': 1.0,
#                                                         'elem_power_from_sky_mean': 1.61867301251183e-15,
#                                                         'elem_power_to_det_mean': 7.06677154429609e-16},
#                                                'lens1': {'elem_effic_mean': 0.963240195309819,
#                                                          'elem_power_from_sky_mean': 4.252992257287599,
#                                                          'elem_power_to_det_mean': 0.0001357945719933385},
#                                                'lens2': {'elem_effic_mean': 0.965867206281993,
#                                                          'elem_power_from_sky_mean': 3.5864828591919777,
#                                                          'elem_power_to_det_mean': 0.00013546515019997608},
#                                                'lowpass': {'elem_effic_mean': 0.9405,
#                                                            'elem_power_from_sky_mean': 3.46412813421019,
#                                                            'elem_power_to_det_mean': 2.8882226641758637e-21},
#                                                'nylon_filt': {'elem_effic_mean': 0.9825750000000002,
#                                                               'elem_power_from_sky_mean': 4.328152098123154,
#                                                               'elem_power_to_det_mean': 0.0025216849239333736},
#                                                'synchrotron': {'elem_effic_mean': 1.0,
#                                                                'elem_power_from_sky_mean': 5.118472529843581e-13,
#                                                                'elem_power_to_det_mean': 2.228659642664501e-13},
#                                                'window': {'elem_effic_mean': 0.9881980546310497,
#                                                           'elem_power_from_sky_mean': 4.101189917272162,
#                                                           'elem_power_to_det_mean': 0.07265523099015334}},
#                                     'popt': 2.367419067264809,
#                                     'psat': 6.113},
#                           'MF2_2': {'Gdyn': 211.41411794629644,
#                                     'band_highedge': 172.05,
#                                     'band_lowedge': 137.95,
#                                     'bandcenter': 155.0,
#                                     'corr_fact': 1.0021587070150602,
#                                     'effic': 0.4632223862696634,
#                                     'fractional_bandwidth': 0.22,
#                                     'nep_phonon': 12.515191932262697,
#                                     'nep_photon': 34.43482032437395,
#                                     'nep_readout': 11.730074815917089,
#                                     'net': 223.95619646873675,
#                                     'netwafer': 13.61945532594936,
#                                     'optics': {'ApStop': {'elem_effic_mean': 0.921,
#                                                           'elem_power_from_sky_mean': 5.038956663685349,
#                                                           'elem_power_to_det_mean': 0.00010798467053081983},
#                                                'RTMLI_10': {'elem_effic_mean': 0.99601,
#                                                             'elem_power_from_sky_mean': 5.128434474581009,
#                                                             'elem_power_to_det_mean': 0.13527627454237565},
#                                                'alumina_filt': {'elem_effic_mean': 0.9508371493823903,
#                                                                 'elem_power_from_sky_mean': 5.754851782826027,
#                                                                 'elem_power_to_det_mean': 0.33613475677558974},
#                                                'atmosphere': {'elem_effic_mean': 0.9669287996700879,
#                                                               'elem_power_from_sky_mean': 3.487235330629191,
#                                                               'elem_power_to_det_mean': 1.6698406847374025},
#                                                'baffle': {'elem_effic_mean': 0.99,
#                                                           'elem_power_from_sky_mean': 4.59431593995236,
#                                                           'elem_power_to_det_mean': 0.6134933706138768},
#                                                'cmb': {'elem_effic_mean': 1.0,
#                                                        'elem_power_from_sky_mean': 0.0,
#                                                        'elem_power_to_det_mean': 0.1140448146001862},
#                                                'detector': {'elem_effic_mean': 0.68,
#                                                             'elem_power_from_sky_mean': 4.176990103573611,
#                                                             'elem_power_to_det_mean': 0.0},
#                                                'dust': {'elem_effic_mean': 1.0,
#                                                         'elem_power_from_sky_mean': 4.669592912292079e-15,
#                                                         'elem_power_to_det_mean': 2.161608146246925e-15},
#                                                'lens1': {'elem_effic_mean': 0.9528034579628321,
#                                                          'elem_power_from_sky_mean': 5.288878875073921,
#                                                          'elem_power_to_det_mean': 3.4068486104533504e-05},
#                                                'lens2': {'elem_effic_mean': 0.9570467227971952,
#                                                          'elem_power_from_sky_mean': 4.640926037543249,
#                                                          'elem_power_to_det_mean': 3.26021583648222e-05},
#                                                'lowpass': {'elem_effic_mean': 0.9405,
#                                                            'elem_power_from_sky_mean': 4.441244129264871,
#                                                            'elem_power_to_det_mean': 2.3175610582097604e-32},
#                                                'nylon_filt': {'elem_effic_mean': 0.963765,
#                                                               'elem_power_from_sky_mean': 5.487666245379956,
#                                                               'elem_power_to_det_mean': 0.009217847185076728},
#                                                'synchrotron': {'elem_effic_mean': 1.0,
#                                                                'elem_power_from_sky_mean': 1.7954757713722409e-13,
#                                                                'elem_power_to_det_mean': 8.112732134104877e-14},
#                                                'window': {'elem_effic_mean': 0.9870616788804638,
#                                                           'elem_power_from_sky_mean': 4.920875736047116,
#                                                           'elem_power_to_det_mean': 0.18440031041305663}},
#                                     'popt': 3.0625827141826476,
#                                     'psat': 7.5360000000000005},
#                           'defaults': {'Tc': 0.16,
#                                        'Yield': 0.8,
#                                        'elevation': 50.0,
#                                        'pwv': 321.0,
#                                        'read_frac': 0.05,
#                                        'site': 'Pole',
#                                        'waist_factor': 3.0}},
#  'input_id': '20220524',
#  'runtime': '2022/05/26 17:15:45',
#  'variation': 'BaseModel'}
